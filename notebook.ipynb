# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('train.csv')
df = df.set_index('id')
df.head()
# Out:
#                                               name  \
# id
# 22267382  Modern and Cozy Large Studio in Brooklyn
# 2473861           Royal Harlem TRIPLEX Home 5 Beds
# 25079703                 Sunny East Village Studio
# 9342478         Beautiful, airy, light-filled room
# 4866426        Private Room in Prime Brooklyn Spot
#
#                                                     summary  \
# id
# 22267382  Modern large studio with new amenities and app...
# 2473861   Harlem is back and so gorgeous! Visit and expl...
# 25079703  Clean, hip and well designed sun drenched East...
# 9342478   Private, spacious, comfortable room in 2-bed f...
# 4866426   Comfy, quiet and big private room in a three b...
#
#                                                       space  \
# id
# 22267382  Our place is a little quiet sanctuary in the h...
# 2473861   Harlem is back and so gorgeous! Visit and expl...
# 25079703  This is a rare East Village studio with it's h...
# 9342478   Big closet, two big windows, tall ceiling and ...
# 4866426   This big old apartment that we love and take c...
#
#                                                 description  \
# id
# 22267382  Modern large studio with new amenities and app...
# 2473861   Harlem is back and so gorgeous! Visit and expl...
# 25079703  Clean, hip and well designed sun drenched East...
# 9342478   Private, spacious, comfortable room in 2-bed f...
# 4866426   Comfy, quiet and big private room in a three b...
#
#          experiences_offered  \
# id
# 22267382                none
# 2473861                 none
# 25079703                none
# 9342478                 none
# 4866426                 none
#
#                                       neighborhood_overview  \
# id
# 22267382  BAM, Barclays, Brooklyn City Point, Fort Green...
# 2473861   HARLEM is a piece of real NY history overflowi...
# 25079703  East Village is one of the last remaining neig...
# 9342478   One block from Morgan L stop. Super cool area....
# 4866426   I absolutely love this neighborhood - right at...
#
#                                                       notes  \
# id
# 22267382                                                NaN
# 2473861   HARLEM RESTAURANTS Red Rooster Harlem -- excel...
# 25079703                                                NaN
# 9342478                                                 NaN
# 4866426   Just a note about the space: The window in you...
#
#                                                     transit  \
# id
# 22267382                          Subway: 2,3,4,5,A,C,B,Q,G
# 2473861   PUBLIC TRANSPORTATION: Conveniently near all p...
# 25079703                                                NaN
# 9342478                                                 NaN
# 4866426   Super convenient to almost all subway lines. A...
#
#                                                      access  \
# id
# 22267382  Washer/Dryer Dishwasher Internet Gym Roof Top ...
# 2473861                              The WHOLE ENTIRE HOUSE
# 25079703  You'll have access to the entire space - it's ...
# 9342478                                                 NaN
# 4866426   Your room has a very comfortable queen sized b...
#
#                                                 interaction  \
# id
# 22267382  Depending on the time of your visit, I'll be h...
# 2473861                                                 NaN
# 25079703     Very responsive via phone call, text or email.
# 9342478                                                 NaN
# 4866426   We are my husband Joaquin and I, our sweet new...
#
#                                                 house_rules   host_id  \
# id
# 22267382  - Please be respectful of our neighbors, no lo...   1910170
# 2473861   Smoking, pets and unaccounted guests NOT permi...   8826175
# 25079703                                                NaN   4383563
# 9342478                                                 NaN  10406276
# 4866426   This house is shoes off. Thank you! No guests ...   2346300
#
#                   host_name  host_since  \
# id
# 22267382           Katarina  2012-03-12
# 2473861              Grover  2013-09-14
# 25079703             Zander  2012-12-11
# 9342478            Kathleen  2013-12-03
# 4866426   Donna And Joaquin  2012-05-11
#
#                                    host_location  \
# id
# 22267382  Los Angeles, California, United States
# 2473861        New York, New York, United States
# 25079703       New York, New York, United States
# 9342478        New York, New York, United States
# 4866426                             Brooklyn, NY
#
#                                                  host_about  \
# id
# 22267382                   Traveler, Artist, Philanthropist
# 2473861   As the owners of the property we have realized...
# 25079703  New York City based, currently working as a te...
# 9342478   Australian actress living in New York. Love ex...
# 4866426   Of the many reasons I love to travel perhaps t...
#
#           host_response_time host_response_rate  host_acceptance_rate  \
# id
# 22267382                 NaN                NaN                   NaN
# 2473861       within an hour               100%                   NaN
# 25079703  within a few hours               100%                   NaN
# 9342478                  NaN                NaN                   NaN
# 4866426   within a few hours               100%                   NaN
#
#          host_is_superhost host_neighbourhood  host_listings_count  \
# id
# 22267382                 f        Fort Greene                  1.0
# 2473861                  f       Mid-Wilshire                  4.0
# 25079703                 f       East Village                  1.0
# 9342478                  f       Williamsburg                  1.0
# 4866426                  t        Boerum Hill                  1.0
#
#                                          host_verifications  \
# id
# 22267382  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 2473861     ['email', 'phone', 'reviews', 'manual_offline']
# 25079703   ['email', 'phone', 'facebook', 'reviews', 'kba']
# 9342478                ['email', 'phone', 'reviews', 'kba']
# 4866426   ['email', 'phone', 'reviews', 'jumio', 'govern...
#
#          host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# id
# 22267382                    t                      t            Fort Greene
# 2473861                     t                      t                 Harlem
# 25079703                    t                      t           East Village
# 9342478                     t                      t           Williamsburg
# 4866426                     t                      t            Boerum Hill
#
#          neighbourhood_group_cleansed      city state  zipcode    market  \
# id
# 22267382                     Brooklyn  Brooklyn    NY  11217.0  New York
# 2473861                     Manhattan  New York    NY  10027.0  New York
# 25079703                    Manhattan  New York    NY  10009.0  New York
# 9342478                      Brooklyn  Brooklyn    NY  11237.0  New York
# 4866426                      Brooklyn  Brooklyn    NY  11201.0  New York
#
#          country_code        country property_type        room_type  \
# id
# 22267382           US  United States          Loft  Entire home/apt
# 2473861            US  United States         House  Entire home/apt
# 25079703           US  United States     Apartment  Entire home/apt
# 9342478            US  United States     Apartment     Private room
# 4866426            US  United States     Apartment     Private room
#
#           accommodates  bathrooms  bedrooms  beds  bed_type  \
# id
# 22267382             2        1.0       1.0   1.0  Real Bed
# 2473861              8        1.0       3.0   5.0  Real Bed
# 25079703             2        1.0       0.0   1.0  Real Bed
# 9342478              1        1.0       1.0   1.0  Real Bed
# 4866426              2        1.0       1.0   1.0  Real Bed
#
#                                                   amenities  square_feet  \
# id
# 22267382  {Wifi,"Air conditioning",Kitchen,Gym,Breakfast...          NaN
# 2473861   {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN
# 25079703  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...          NaN
# 9342478   {Wifi,"Air conditioning",Kitchen,Heating,Washe...          NaN
# 4866426   {Internet,Wifi,"Air conditioning",Kitchen,Brea...          NaN
#
#           price  guests_included extra_people  minimum_nights  maximum_nights  \
# id
# 22267382  145.0                2       $30.00               7              12
# 2473861   175.0                3       $19.00               3              30
# 25079703  180.0                1        $0.00               2            1125
# 9342478    42.0                1        $0.00               3            1125
# 4866426    80.0                1       $14.00               1              90
#
#           number_of_reviews first_review last_review  review_scores_rating  \
# id
# 22267382                  6   2018-01-01  2018-07-03                 100.0
# 2473861                 137   2014-04-15  2018-10-20                  91.0
# 25079703                  3   2018-07-26  2018-10-14                 100.0
# 9342478                   0          NaN         NaN                   NaN
# 4866426                 144   2015-01-31  2018-10-17                  97.0
#
#           review_scores_accuracy  review_scores_cleanliness  \
# id
# 22267382                    10.0                       10.0
# 2473861                      9.0                        9.0
# 25079703                    10.0                        9.0
# 9342478                      NaN                        NaN
# 4866426                     10.0                       10.0
#
#           review_scores_checkin  review_scores_communication  \
# id
# 22267382                   10.0                         10.0
# 2473861                     9.0                          9.0
# 25079703                    9.0                         10.0
# 9342478                     NaN                          NaN
# 4866426                    10.0                         10.0
#
#           review_scores_location  review_scores_value instant_bookable  \
# id
# 22267382                    10.0                 10.0                t
# 2473861                      9.0                  9.0                t
# 25079703                    10.0                 10.0                f
# 9342478                      NaN                  NaN                f
# 4866426                     10.0                 10.0                f
#
#          is_business_travel_ready cancellation_policy  \
# id
# 22267382                        f            flexible
# 2473861                         f            moderate
# 25079703                        f            moderate
# 9342478                         f            flexible
# 4866426                         f            flexible
#
#          require_guest_profile_picture require_guest_phone_verification  \
# id
# 22267382                             f                                f
# 2473861                              f                                f
# 25079703                             f                                f
# 9342478                              f                                f
# 4866426                              f                                f
#
#           calculated_host_listings_count  reviews_per_month
# id
# 22267382                               1               0.59
# 2473861                                3               2.47
# 25079703                               1               0.89
# 9342478                                1                NaN
# 4866426                                1               3.14

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Basic data cleaning

# %%
cleaned = df.copy()
cleaned['transit'] = 1-df['transit'].isna().astype(int) #there is transportation listed
cleaned['host_is_superhost'] = (df['host_is_superhost'] == 't').astype(int)
cleaned['host_has_profile_pic'] = (df['host_has_profile_pic'] == 't').astype(int)
cleaned['host_identity_verified'] = (df['host_identity_verified'] == 't').astype(int)
cleaned['instant_bookable'] = (df['instant_bookable'] == 't').astype(int)
cleaned['is_business_travel_ready'] = (df['is_business_travel_ready'] == 't').astype(int)
cleaned['require_guest_profile_picture'] = (df['require_guest_profile_picture'] == 't').astype(int)
cleaned['require_guest_phone_verification'] = (df['require_guest_phone_verification'] == 't').astype(int)
cleaned['extra_people'] = df['extra_people'].str.replace('$', '').astype('float')

# %%
#more complicated cleaning

#clean amenities
def clean_amenities(x):
    return x.strip('{').strip('}').replace('"','').split(',')
df['amenities'] = df['amenities'].apply(clean_amenities)
mlb = MultiLabelBinarizer()
cleaned[mlb.classes_] = mlb.fit_transform(df['amenities'])

# %%
#one hot encode bed type
bed_type_ohe = OneHotEncoder()
bed_type_fit = bed_type_ohe.fit_transform(df[['bed_type']])
cleaned[bed_type_ohe.categories_[0]] = bed_type_fit.toarray() #stackoverflow诚不欺我

# %%
#rate cancellation policy
dict_cancellation_policy = {'flexible': 1, 'moderate': 2, 'super_strict_60': 7,
   'strict_14_with_grace_period': 5, 'super_strict_30': 6, 'long_term': 4,
   'strict': 3} #reference: https://www.airbnb.com/help/article/475
cleaned['cancellation_policy'] = df['cancellation_policy'].apply(lambda x: dict_cancellation_policy[x])

# host response time
dict_response_time = {np.NaN: 0, 'within an hour': 1, 'within a few hours': 2, 'within a day': 3,'a few days or more': 4}
cleaned['host_response_time'] = df['host_response_time'].apply(lambda x: dict_response_time[x])

# %%
#last review first review difference
time_diff = pd.to_datetime(df['last_review']) - pd.to_datetime(df['first_review'])
cleaned['time_diff'] = time_diff.dt.days

#host history
first_date = min(pd.to_datetime(df['host_since']))
cleaned['host history'] = (pd.to_datetime(df['host_since']) - first_date).dt.days

# %%
mlb_v = MultiLabelBinarizer()
cleaned[mlb_v.classes_] = mlb_v.fit_transform(df['host_verifications'].str.replace('[', '').str.replace(']', '').str.replace('\'', '').str.replace(' ', '').str.split(','))

# %%
#neighborhood encode bed type
neighbor_ohe = OneHotEncoder()
neighbor_fit = neighbor_ohe.fit_transform(df[['neighbourhood_group_cleansed']])
cleaned[neighbor_ohe.categories_[0]] = neighbor_fit.toarray()

# %%
#market encode bed type
market_ohe = OneHotEncoder()
market_fit = market_ohe.fit_transform(df[['market']])
cleaned[market_ohe.categories_[0]] = market_fit.toarray()

# %%
cleaned['country'] = (df['country_code'] == 'US').astype(int)

# %%
#property encode bed type
property_ohe = OneHotEncoder()
property_fit = property_ohe.fit_transform(df[['property_type']])
cleaned[property_ohe.categories_[0]] = property_fit.toarray()

# %%
#room type encode bed type
room_ohe = OneHotEncoder()
room_fit = room_ohe.fit_transform(df[['room_type']])
cleaned[room_ohe.categories_[0]] = room_fit.toarray()

# %%
#host_response_rate
cleaned['host_response_rate'] = df['host_response_rate'].str.strip('%').astype(float)

# %% [markdown]
# # Get training matrix

# %%
string_cols = ['name', 'summary', 'space', 'description', 'experiences_offered',
       'neighborhood_overview', 'notes', 'access','interaction', 'house_rules', 'host_id', 'host_name',
               'host_location', 'host_acceptance_rate', 'host_response_rate', 'host_about', 'host_neighbourhood', 'host_since',
     '','host_verifications', 'neighbourhood_group_cleansed', 'property_type', 'room_type', 'neighbourhood_cleansed',  
               'city', 'bed_type', 'amenities', 'state', 'zipcode', 'market', 'country_code', 'first_review', 'last_review']

# %%
# np.array(cleaned.columns)
X2 = cleaned.drop(string_cols, axis=1)
y2 = cleaned['price']

# %%
X2_train, X2_val, y2_train, y2_val = train_test_split(X2, y2, test_size=0.25, shuffle=True)

# %%
params = {'max_depth': range(1, 20, 1),
         'min_child_weight': range(1, 10, 1),
          'eta': np.arange(0.01, 0.2, 0.02),
         }

# %%
rcv = RandomizedSearchCV(xgb, params)

# %%
X2_train = X2_train.drop(X2_extra_features, axis=1)
X2_val = X2_val.drop(X2_extra_features, axis=1)

# %%
cleaned_X2 = X2.drop(X2_extra_features, axis=1)

# %%
rcv.fit(cleaned_X2, y2)
# Out:
# RandomizedSearchCV(estimator=XGBRegressor(base_score=None, booster='gbtree',
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric='rmse',
#                                           feature_types=None, gamma=None,
#                                           gpu_id=None, grow_policy='lossguide',
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learni...
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           predictor=None, random_state=None, ...),
#                    param_distributions={'eta': array([0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19]),
#                                         'max_depth': range(1, 20),
#                                         'min_child_weight': range(1, 10)})

# %%
best_xgb = rcv.best_estimator_
best_xgb
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.08999999999999998,
#              eval_metric='rmse', feature_types=None, gamma=None, gpu_id=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %%
best_xgb.fit(X2_train, y2_train)
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.08999999999999998,
#              eval_metric='rmse', feature_types=None, gamma=None, gpu_id=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %%
# train accuracy - RMSE
sum((xgb.predict(X2_train) - y2_train)**2) / len(y2_train)
# Out:
# 4010.440359672981

# %%
# val accuracy
sum((xgb.predict(X2_val) - y2_val)**2) / len(y2_val)
# Out:
# 4320.213494114515

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(booster='gbtree', tree_method = 'approx', grow_policy='lossguide', objective='reg:squarederror', eval_metric = 'rmse') #max_depth=1000, n_estimators= 1000, grow_policy='lossguide'
xgb
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, gpu_id=None, grow_policy='lossguide',
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, predictor=None, random_state=None, ...)

# %%
xgb.fit(X2_train, y2_train)
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, gpu_id=None, grow_policy='lossguide',
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, predictor=None, random_state=None, ...)

# %%
# train accuracy - RMSE
sum((xgb.predict(X2_train) - y2_train)**2) / len(y2_train)
# Out:
# 2937.182870966965

# %%
# val accuracy
sum((xgb.predict(X2_val) - y2_val)**2) / len(y2_val)
# Out:
# 7539.729965601792

# %%
test = pd.read_csv('test.csv')
test = test.set_index('id')
test.head()
# Out:
#                                                       name  \
# id
# 19307997               Super Lux 2BR in Downtown Manhattan
# 20176193       Vintage Eclectic Brownstone Pad in Brooklyn
# 19485371                          Spacious Harlem Hideaway
# 13079990                  Spacius private room in Brooklyn
# 22339757  *Dg) Delightful Private Room 20 min to Manhattan
#
#                                                     summary  \
# id
# 19307997  Prepare to be WOWED! This spectacularly bright...
# 20176193  Ideal for romantic, creative types, this is an...
# 19485371  Postive Vibes . This is our Harlem tree house,...
# 13079990  Newly renovated apartment, its a 3 bedroom apa...
# 22339757  Hi my home is only 2 blocks from the subway st...
#
#                                                       space  \
# id
# 19307997  Top of the line Wolf and Sub-Zero appliances, ...
# 20176193  Not your typical New York abode, my apartment ...
# 19485371  The private room is very spacious and cozy. Th...
# 13079990  3 bedroom apartment, 1 full bathroom, living r...
# 22339757                                                NaN
#
#                                                 description  \
# id
# 19307997  Prepare to be WOWED! This spectacularly bright...
# 20176193  Ideal for romantic, creative types, this is an...
# 19485371  Postive Vibes . This is our Harlem tree house,...
# 13079990  Newly renovated apartment, its a 3 bedroom apa...
# 22339757  Hi my home is only 2 blocks from the subway st...
#
#          experiences_offered  \
# id
# 19307997                none
# 20176193                none
# 19485371                none
# 13079990                none
# 22339757                none
#
#                                       neighborhood_overview  \
# id
# 19307997                                                NaN
# 20176193  Bed Stuy is a diverse historic neighborhood wi...
# 19485371  You are in a Cultural Haven full of restaurant...
# 13079990                                                NaN
# 22339757                                                NaN
#
#                                                       notes  \
# id
# 19307997                                                NaN
# 20176193  This is an actual unique living experience whe...
# 19485371  We also keep cucumber water in the fridge feel...
# 13079990                                                NaN
# 22339757                                                NaN
#
#                                                     transit  \
# id
# 19307997                                                NaN
# 20176193  Close to buses and subways there is also free ...
# 19485371  Train, uber or a taxi. (Extremely taxi accessi...
# 13079990  There is the Mta 3 train Sutter stop, also the...
# 22339757                                                NaN
#
#                                                      access  \
# id
# 19307997                                                NaN
# 20176193  Entrance hallway, living room, bedroom, kitche...
# 19485371                 Private Room, Kitchen And Bathroom
# 13079990                                                NaN
# 22339757                                                NaN
#
#                                                 interaction  \
# id
# 19307997           electronic lock ensures 24 hour check-in
# 20176193  I'm very social but understand the need for my...
# 19485371  Very open to communication. If you have any qu...
# 13079990                                                NaN
# 22339757                                                NaN
#
#                                                 house_rules    host_id  \
# id
# 19307997                                                NaN  105703386
# 20176193  Hi there. Thank you so much for taking the tim...   10208778
# 19485371  If you are cooking we request you wash your di...   74238783
# 13079990                           Clean up after yourself.   53324604
# 22339757  - no illegal downloads, please do not or it wi...  154258141
#
#          host_name  host_since  \
# id
# 19307997     Derek  2016-11-30
# 20176193   Russell  2013-11-23
# 19485371  Cardelle  2016-05-27
# 13079990      Nana  2016-01-04
# 22339757     Elsie  2017-10-11
#
#                                             host_location  \
# id
# 19307997                New York, New York, United States
# 20176193                New York, New York, United States
# 19485371  Washington, District of Columbia, United States
# 13079990                New York, New York, United States
# 22339757                                               US
#
#                                                  host_about  \
# id
# 19307997                                                NaN
# 20176193  I am an artist and small business owner in Bro...
# 19485371  Hey Folks!! My name is cardelle and I'm in sch...
# 13079990  Musician Residing in Brooklyn, NY for the past...
# 22339757                                                NaN
#
#          host_response_time host_response_rate  host_acceptance_rate  \
# id
# 19307997                NaN                NaN                   NaN
# 20176193       within a day                90%                   NaN
# 19485371                NaN                NaN                   NaN
# 13079990                NaN                NaN                   NaN
# 22339757     within an hour               100%                   NaN
#
#          host_is_superhost host_neighbourhood  host_listings_count  \
# id
# 19307997                 f  Battery Park City                  1.0
# 20176193                 f                NaN                  1.0
# 19485371                 f   Hamilton Heights                  1.0
# 13079990                 f        Brownsville                  1.0
# 22339757                 f           Bushwick                 12.0
#
#                                          host_verifications  \
# id
# 19307997  ['email', 'phone', 'google', 'reviews', 'jumio...
# 20176193        ['email', 'phone', 'reviews', 'work_email']
# 19485371  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 13079990          ['email', 'phone', 'facebook', 'reviews']
# 22339757                                 ['email', 'phone']
#
#          host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# id
# 19307997                    t                      t      Battery Park City
# 20176193                    t                      f     Bedford-Stuyvesant
# 19485371                    t                      t                 Harlem
# 13079990                    t                      f            Brownsville
# 22339757                    t                      f               Bushwick
#
#          neighbourhood_group_cleansed      city state  zipcode    market  \
# id
# 19307997                    Manhattan  New York    NY  10004.0  New York
# 20176193                     Brooklyn  Brooklyn    NY  11216.0  New York
# 19485371                    Manhattan  New York    NY  10031.0  New York
# 13079990                     Brooklyn  Brooklyn    NY  11212.0  New York
# 22339757                     Brooklyn  Brooklyn    NY    11221  New York
#
#          country_code        country property_type        room_type  \
# id
# 19307997           US  United States   Condominium  Entire home/apt
# 20176193           US  United States     Apartment  Entire home/apt
# 19485371           US  United States     Apartment     Private room
# 13079990           US  United States     Apartment     Private room
# 22339757           US  United States     Apartment     Private room
#
#           accommodates  bathrooms  bedrooms  beds  bed_type  \
# id
# 19307997             4        2.0       2.0   2.0  Real Bed
# 20176193             2        1.0       2.0   1.0  Real Bed
# 19485371             1        1.0       1.0   1.0  Real Bed
# 13079990             2        1.0       1.0   1.0  Real Bed
# 22339757             3        2.0       1.0   2.0  Real Bed
#
#                                                   amenities  square_feet  \
# id
# 19307997  {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...          NaN
# 20176193  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN
# 19485371  {Wifi,"Air conditioning",Kitchen,"Smoking allo...          NaN
# 13079990  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,"...          NaN
# 22339757  {Wifi,"Air conditioning",Kitchen,"Free street ...          NaN
#
#           guests_included extra_people  minimum_nights  maximum_nights  \
# id
# 19307997                1        $0.00               2            1125
# 20176193                1        $0.00               2               5
# 19485371                1       $20.00               1               3
# 13079990                1        $0.00               1               4
# 22339757                2       $10.00               2            1125
#
#           number_of_reviews first_review last_review  review_scores_rating  \
# id
# 19307997                  0          NaN         NaN                   NaN
# 20176193                 22   2017-08-16  2018-10-28                  97.0
# 19485371                  6   2017-07-01  2017-12-15                 100.0
# 13079990                  7   2016-05-23  2016-10-20                  83.0
# 22339757                 14   2018-02-02  2018-10-14                  74.0
#
#           review_scores_accuracy  review_scores_cleanliness  \
# id
# 19307997                     NaN                        NaN
# 20176193                    10.0                        9.0
# 19485371                    10.0                        9.0
# 13079990                     9.0                        8.0
# 22339757                     7.0                        7.0
#
#           review_scores_checkin  review_scores_communication  \
# id
# 19307997                    NaN                          NaN
# 20176193                   10.0                         10.0
# 19485371                   10.0                         10.0
# 13079990                   10.0                          9.0
# 22339757                    9.0                          8.0
#
#           review_scores_location  review_scores_value instant_bookable  \
# id
# 19307997                     NaN                  NaN                f
# 20176193                    10.0                 10.0                f
# 19485371                    10.0                 10.0                t
# 13079990                     8.0                  9.0                f
# 22339757                     8.0                  8.0                t
#
#          is_business_travel_ready          cancellation_policy  \
# id
# 19307997                        f                     flexible
# 20176193                        f                     flexible
# 19485371                        f                     flexible
# 13079990                        f                     flexible
# 22339757                        f  strict_14_with_grace_period
#
#          require_guest_profile_picture require_guest_phone_verification  \
# id
# 19307997                             f                                f
# 20176193                             f                                f
# 19485371                             f                                f
# 13079990                             f                                f
# 22339757                             f                                f
#
#           calculated_host_listings_count  reviews_per_month
# id
# 19307997                               1                NaN
# 20176193                               1               1.48
# 19485371                               1               0.37
# 13079990                               1               0.23
# 22339757                               9               1.53

# %%
def clean(df):

    cleaned = df.copy()
    cleaned['transit'] = 1-df['transit'].isna().astype(int) #there is transportation listed
    cleaned['host_is_superhost'] = (df['host_is_superhost'] == 't').astype(int)
    cleaned['host_has_profile_pic'] = (df['host_has_profile_pic'] == 't').astype(int)
    cleaned['host_identity_verified'] = (df['host_identity_verified'] == 't').astype(int)
    cleaned['instant_bookable'] = (df['instant_bookable'] == 't').astype(int)
    cleaned['is_business_travel_ready'] = (df['is_business_travel_ready'] == 't').astype(int)
    cleaned['require_guest_profile_picture'] = (df['require_guest_profile_picture'] == 't').astype(int)
    cleaned['require_guest_phone_verification'] = (df['require_guest_phone_verification'] == 't').astype(int)
    cleaned['extra_people'] = df['extra_people'].str.replace('$', '').astype('float')

    #more complicated cleaning

    #clean amenities
    def clean_amenities(x):
        return x.strip('{').strip('}').replace('"','').split(',')
    df['amenities'] = df['amenities'].apply(clean_amenities)
    mlb = MultiLabelBinarizer()
    cleaned[mlb.classes_] = mlb.fit_transform(df['amenities'])

    #one hot encode bed type
    bed_type_ohe = OneHotEncoder()
    bed_type_fit = bed_type_ohe.fit_transform(df[['bed_type']])
    cleaned[bed_type_ohe.categories_[0]] = bed_type_fit.toarray() #stackoverflow诚不欺我

    #rate cancellation policy
    dict_cancellation_policy = {'flexible': 1, 'moderate': 2, 'super_strict_60': 7,
       'strict_14_with_grace_period': 5, 'super_strict_30': 6, 'long_term': 4,
       'strict': 3} #reference: https://www.airbnb.com/help/article/475
    cleaned['cancellation_policy'] = df['cancellation_policy'].apply(lambda x: dict_cancellation_policy[x])

    # host response time
    dict_response_time = {np.NaN: 0, 'within an hour': 1, 'within a few hours': 2, 'within a day': 3,'a few days or more': 4}
    cleaned['host_response_time'] = df['host_response_time'].apply(lambda x: dict_response_time[x])

    #last review first review difference
    time_diff = pd.to_datetime(df['last_review']) - pd.to_datetime(df['first_review'])
    cleaned['time_diff'] = time_diff.dt.days

    #host history
    first_date = min(pd.to_datetime(df['host_since']))
    cleaned['host history'] = (pd.to_datetime(df['host_since']) - first_date).dt.days

    mlb_v = MultiLabelBinarizer()
    cleaned[mlb_v.classes_] = mlb_v.fit_transform(df['host_verifications'].str.replace('[', '').str.replace(']', '').str.replace('\'', '').str.replace(' ', '').str.split(','))

    #neighborhood encode bed type
    neighbor_ohe = OneHotEncoder()
    neighbor_fit = neighbor_ohe.fit_transform(df[['neighbourhood_group_cleansed']])
    cleaned[neighbor_ohe.categories_[0]] = neighbor_fit.toarray() 

    #market encode bed type
    market_ohe = OneHotEncoder()
    market_fit = market_ohe.fit_transform(df[['market']])
    cleaned[market_ohe.categories_[0]] = market_fit.toarray() 

    cleaned['country'] = (df['country_code'] == 'US').astype(int)

    #property encode bed type
    property_ohe = OneHotEncoder()
    property_fit = property_ohe.fit_transform(df[['property_type']])
    cleaned[property_ohe.categories_[0]] = property_fit.toarray() 

    #room type encode bed type
    room_ohe = OneHotEncoder()
    room_fit = room_ohe.fit_transform(df[['room_type']])
    cleaned[room_ohe.categories_[0]] = room_fit.toarray() 

    #host_response_rate
    cleaned['host_response_rate'] = df['host_response_rate'].str.strip('%').astype(float)
    
    string_cols = ['name', 'summary', 'space', 'description', 'experiences_offered',
       'neighborhood_overview', 'notes', 'access','interaction', 'house_rules', 'host_id', 'host_name',
               'host_location', 'host_acceptance_rate', 'host_response_rate', 'host_about', 'host_neighbourhood', 'host_since',
     '','host_verifications', 'neighbourhood_group_cleansed', 'property_type', 'room_type', 'neighbourhood_cleansed',  
               'city', 'bed_type', 'amenities', 'state', 'zipcode', 'market', 'country_code', 'first_review', 'last_review']
    
    X2 = cleaned.drop(string_cols, axis=1)
    
    return X2

# %%
cleaned_test = clean(test)

# %%
test_extra_features = list(set(cleaned_test.columns) - set(X2.columns)) #columns in test that are not in X2

# %%
cleaned_test = cleaned_test.drop(test_extra_features, axis=1)

# %%
#reorder the features
cleaned_test = cleaned_test[X2_train.columns]

# %%
test_pred = best_xgb.predict(cleaned_test)

# %%
pd.DataFrame(index=test.index, data=test_pred, columns=['Predicted']).to_csv('preds2-1.csv')
